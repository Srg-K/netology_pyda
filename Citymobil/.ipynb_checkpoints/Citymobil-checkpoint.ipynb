# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport
from scipy.stats.mstats import kruskal
from statsmodels.sandbox.stats.multicomp import multipletests
import statsmodels.api as sm
from scipy.stats import norm
import matplotlib.pyplot as plt
from tqdm.auto import tqdm

plt.style.use('ggplot')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv('test_case_dataset.csv')
data.head()
# Out:
#         DRIVER SPLIT  TRANSFERED  ORDERS  CONTRIBUTION
# 0  194742262.0     A  2020-07-11       1          51.6
# 1  187188066.0     A  2020-07-12       4         322.6
# 2  198961854.0     B  2020-07-13       2         527.8
# 3  220022439.0     B  2020-07-11       8          81.8
# 4  132824354.0     A  2020-07-11       1          75.8

# %%
data.profile_report()
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.8.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-11-22 15:11:04.107614&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# У нас есть пропущенные значения - надо их почистить
#
# Transfered содержит 4 уникальных значения, то есть у нас данные только за 4 дня - было бы неплохо получить данные хотя бы за неделю, чтобы учесть "сезонность" (очевидно, что поведение пользователей будет разным в будние дни и выходные, пятница будет отличаться от других будних дней и т.д.)
#
# Значения параметра Orders очевидно не распределены нормально, их распределение похоже на логнормальное
#
# Параметры Orders и Contribution коррелируют между собой не очень высоко (<0.5), можем предположить, что рост количества поездок не всегда положительно сказывается на доходе

# %%
df = data.dropna()

# %%
df.sort_values(by='DRIVER')
# Out:
#            DRIVER SPLIT  TRANSFERED  ORDERS  CONTRIBUTION
# 4845       1989.0     A  2020-07-11       2      284.4000
# 1729       1989.0     A  2020-07-10       3      370.4000
# 4101       1989.0     A  2020-07-13       5     1566.0000
# 743        1989.0     A  2020-07-12       3      613.2000
# 5517       3458.0     B  2020-07-12       6      326.4002
# ...           ...   ...         ...     ...           ...
# 4124  224727971.0     B  2020-07-13      13    -1020.6766
# 1329  224727971.0     B  2020-07-10      12    -1012.5820
# 566   224727971.0     B  2020-07-12      15    -1073.3598
# 2342  224729583.0     C  2020-07-11      10      729.8000
# 5872  224729583.0     C  2020-07-10       8      594.8000
#
# [6926 rows x 5 columns]

# %%
df_driver = df.groupby(['DRIVER','SPLIT']).mean().reset_index()

# %%
df_driver.head()
# Out:
#    DRIVER SPLIT  ORDERS  CONTRIBUTION
# 0  1989.0     A    3.25    708.500000
# 1  3458.0     B    4.00    267.500100
# 2  7917.0     A    4.00    631.600000
# 3  9308.0     C   10.50     19.400250
# 4  9724.0     B    4.00    272.299975

# %%
a,b,c = df_driver[df_driver['SPLIT']=='A']['ORDERS'], df_driver[df_driver['SPLIT']=='B']['ORDERS'], df_driver[df_driver['SPLIT']=='C']['ORDERS']

# %%
a,b,c = list(map(float, a)),list(map(float, b)),list(map(float, c))

# %% [markdown]
# Для ненормального распределения с длинным хвостом подойдет ранговый критерий Манна-Уитни (если групп больше двух - многомерное обобщение теста Манна-Уитни - Критерий Краскела-Уоллиса):

# %%
kruskal(a, b, c)
# Out:
# KruskalResult(statistic=6.435298228445068, pvalue=0.04004909853451714)

# %% [markdown]
# P-value < 0.05 - значит, с 95% уровнем значимости отвергаем нулевую гипотезу. То есть одна или более выборок отличаются.
#
# Сравним попарно и применим поправку Бенджамини-Хохберга на множественные сравнения

# %%
kruskal(a, b)
# Out:
# KruskalResult(statistic=6.546426799387685, pvalue=0.010509501190386487)

# %%
kruskal(a, c)
# Out:
# KruskalResult(statistic=0.8794315472574935, pvalue=0.3483574212884173)

# %%
kruskal(b, c)
# Out:
# KruskalResult(statistic=2.2668267159914106, pvalue=0.13217028463335628)

# %%
pvals = [.01,.13,.34]

# %%
p_adjusted = multipletests(pvals, alpha=0.05, method='fdr_bh', is_sorted=True)

# %%
p_adjusted
# Out:
# (array([ True, False, False]),
#  array([0.03 , 0.195, 0.34 ]),
#  0.016952427508441503,
#  0.016666666666666666)

# %%
df_split = df_driver.groupby('SPLIT').mean().reset_index()

# %%
df_split = df_split[['SPLIT','ORDERS','CONTRIBUTION']]

# %%
df_split
# Out:
#   SPLIT    ORDERS  CONTRIBUTION
# 0     A  2.790376    290.033981
# 1     B  3.260894    213.876661
# 2     C  3.060395    255.428020

# %% [markdown]
# Уже "оштрафованные" p-value показывают статистичеки значимые различия между контролем А и тестом Б на уровне значимости 95%.
# Изначально был вопрос о том, повлияло ли изменение на кол-во поездок в день на одного водителя - получается, что в группе Б повлияло в лучшую сторону. Но есть одна проблема - при росте заказов доход Ситимобил упал

# %%
df_driver.CONTRIBUTION.hist(grid=True, bins=100)

# %%
fig = sm.qqplot(df_driver.CONTRIBUTION, color="green")
plt.title("Normal Q-Q Plot")
plt.show()

# %% [markdown]
# Распределение дохода так же не похоже на нормальное, будем опять-таки применять ранговый критерий

# %%
ac,bc,cc = df_driver[df_driver['SPLIT']=='A']['CONTRIBUTION'], df_driver[df_driver['SPLIT']=='B']['CONTRIBUTION'], df_driver[df_driver['SPLIT']=='C']['CONTRIBUTION']

# %%
ac,bc,cc = list(map(float, ac)),list(map(float, bc)),list(map(float, cc))

# %%
kruskal(ac,bc,cc)
# Out:
# KruskalResult(statistic=44.366207390188585, pvalue=2.3227393300238161e-10)

# %%
kruskal(ac,bc)
# Out:
# KruskalResult(statistic=44.02213063498638, pvalue=3.2468401611064265e-11)

# %%
kruskal(ac,cc)
# Out:
# KruskalResult(statistic=6.8135515847131956, pvalue=0.009046865236411144)

# %%
kruskal(bc,cc)
# Out:
# KruskalResult(statistic=15.928247212092764, pvalue=6.578950295420383e-05)

# %% [markdown]
# Видим, что разница в метрике Contribution статзначима. P-value настолько малы, что можем обойтись без поправок на множественные сравнения.
#
# <b>Получается, что мы повлияли на ту метрику, которую хотели, но уронили средний дневной доход компании на водителя - надо разобраться почему так произошло и подумать, как вырастить производительность без снижения дохода (то есть доход наоборот должен увеличиться засчет оборота)</b>
#
# Для оценки данных метрик нам также подойдет Bootstrap. Проанализируем тест с помощью этого метода. Сначала создадим соответствующую функцию (будем проверять средние):

# %%
def get_bootstrap(
    data_column_1, # числовые значения первой выборки
    data_column_2, # числовые значения второй выборки
    boot_it = 1000, # количество бутстрэп-подвыборок
    statistic = np.mean, # интересующая нас статистика
    bootstrap_conf_level = 0.95 # уровень значимости
):
    boot_len = max([len(data_column_1), len(data_column_2)])
    boot_data = []
    for i in tqdm(range(boot_it)): # извлекаем подвыборки
        samples_1 = data_column_1.sample(
            boot_len, 
            replace = True # параметр возвращения
        ).values
        
        samples_2 = data_column_2.sample(
            boot_len, 
            replace = True
        ).values
        
        boot_data.append(statistic(samples_1-samples_2)) # mean() - применяем статистику
        
    pd_boot_data = pd.DataFrame(boot_data)
        
    left_quant = (1 - bootstrap_conf_level)/2
    right_quant = 1 - (1 - bootstrap_conf_level) / 2
    quants = pd_boot_data.quantile([left_quant, right_quant])
        
    p_1 = norm.cdf(
        x = 0, 
        loc = np.mean(boot_data), 
        scale = np.std(boot_data)
    )
    p_2 = norm.cdf(
        x = 0, 
        loc = -np.mean(boot_data), 
        scale = np.std(boot_data)
    )
    p_value = min(p_1, p_2) * 2
        
    # Визуализация
    _, _, bars = plt.hist(pd_boot_data[0], bins = 50)
    for bar in bars:
        if abs(bar.get_x()) <= quants.iloc[0][0] or abs(bar.get_x()) >= quants.iloc[1][0]:
            bar.set_facecolor('red')
        else: 
            bar.set_facecolor('grey')
            bar.set_edgecolor('black')
    
    plt.style.use('ggplot')
    plt.vlines(quants,ymin=0,ymax=50,linestyle='--')
    plt.xlabel('boot_data')
    plt.ylabel('frequency')
    plt.title("Histogram of boot_data")
    plt.show()
       
    return {"boot_data": boot_data, 
            "quants": quants, 
            "p_value": p_value}

# %%
sample_1 = df_driver[df_driver['SPLIT']=='A']['ORDERS']
sample_2 = df_driver[df_driver['SPLIT']=='B']['ORDERS']
sample_3 = df_driver[df_driver['SPLIT']=='C']['ORDERS']

# %%
booted_data_ab = get_bootstrap(sample_1, sample_2)

# %%
booted_data_ab["p_value"]
# Out:
# 2.0488770517781182e-05

# %%
booted_data_ab["quants"]
# Out:
#               0
# 0.025 -0.675774
# 0.975 -0.250984

# %%
booted_data_ac = get_bootstrap(sample_1, sample_3)

# %%
booted_data_ac["p_value"]
# Out:
# 0.012751487336427097

# %%
booted_data_ac["quants"]
# Out:
#               0
# 0.025 -0.475592
# 0.975 -0.051001

# %%
booted_data_bc = get_bootstrap(sample_2, sample_3)

# %%
booted_data_bc["p_value"]
# Out:
# 0.10185119135520579

# %%
booted_data_bc["quants"]
# Out:
#               0
# 0.025 -0.041719
# 0.975  0.437380

# %% [markdown]
# Проверим отличие метрики CONTRIBUTION:

# %%
sample_1 = df_driver[df_driver['SPLIT']=='A']['CONTRIBUTION']
sample_2 = df_driver[df_driver['SPLIT']=='B']['CONTRIBUTION']
sample_3 = df_driver[df_driver['SPLIT']=='C']['CONTRIBUTION']

# %%
booted_data_ab = get_bootstrap(sample_1, sample_2)

# %%
booted_data_ab["p_value"]
# Out:
# 1.0324674260953774e-17

# %%
booted_data_ab["quants"]
# Out:
#                0
# 0.025  58.618896
# 0.975  93.411862

# %%
booted_data_ac = get_bootstrap(sample_1, sample_3)

# %%
booted_data_ac["p_value"]
# Out:
# 0.0002705717706705065

# %%
booted_data_ac["quants"]
# Out:
#                0
# 0.025  16.059992
# 0.975  53.366692

# %%
booted_data_bc = get_bootstrap(sample_2, sample_3)

# %%
booted_data_bc["p_value"]
# Out:
# 6.542384493063255e-07

# %%
booted_data_bc["quants"]
# Out:
#                0
# 0.025 -58.964957
# 0.975 -24.532266

# %%
df_split
# Out:
#   SPLIT    ORDERS  CONTRIBUTION
# 0     A  2.790376    290.033981
# 1     B  3.260894    213.876661
# 2     C  3.060395    255.428020

# %% [markdown]
# Итого: бутсрэп показал статзначимость между A и B (как и предыдущий тест), а так же между A и C (в отличии от предыдущего теста) - низкий p-value, доверительный интервал не включает в себя 0. Различий между B и C, как и в тесте Краскела-Уолеса, не оказалось.
#
# Метрика дохода "прокрасилась" во всех трех тестах.
#
# <b>Получается, что наши изменения дали прирост в Order, но мы стали терять в доходах. Такие изменения выкатывать не нужно, если только они не расчитаны на падение в короткосрочной перспективе и больший рост в долгосрочной (что скорее всего не так). Нужно пересмотреть наши фичи таким образом, чтобы в результате доход не снижался, а наоборот рос засчет роста количества заказов. Новые изменения заново протестировать.
#
# Рекомендации:
# 1. Если можно - сравнивать только две группы (контроль и тест). 3 и более выборок влекут за собой больший риск совершить ошибку I рода
# 2. Захватить все дни недели в тест, чтобы учесть "сезонность"
# 3. Проанализировать данные эксперимента в разрезе различных сегментов водителей, дней недели, времени (например, сравнить данные в часы пик или время, когда дороги свободны)
# </b>
